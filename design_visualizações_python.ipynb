# %% [markdown]
# #### Design e Construção de 50 Visualizações

# %%
from platform import python_version
print(python_version())
# Out:
# 3.11.2

# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %reload_ext watermark
# %watermark --iversions
# Out:
# matplotlib: 3.7.0
# seaborn   : 0.12.2
# numpy     : 1.24.2
# pandas    : 1.5.3

# %%
dados = pd.read_csv('Projeto10/dados/dataset1.csv')

# %%
dados.shape
# Out:
# (244, 7)

# %%
dados.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
dados.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
dados.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
dados.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
plt.figure(figsize = (20, 8))
sns.relplot(x = 'total_bill', y = 'tip', data = dados)
plt.show()

# %%
plt.figure(figsize = (20, 8))
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', data = dados)
plt.show()

# %%
plt.figure(figsize = (20, 8))
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', style = 'smoker', data = dados)
plt.show()

# %%
plt.figure(figsize = (20, 8))
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', style = 'time', data = dados)
plt.show()

# %%
plt.figure(figsize = (20, 8))
sns.relplot(x = 'total_bill', y = 'tip', hue = 'size', data = dados)
plt.show()

# %%
plt.figure(figsize = (20, 8))
sns.relplot(x = 'total_bill', y = 'tip', hue = 'size', data = dados)
plt.show()

# %%
plt.figure(figsize = (20, 8))
sns.relplot(x = 'total_bill', y = 'tip', hue = 'size', sizes = (15, 200), data = dados)
plt.show()

# %%
from scipy import stats

# %%
dados = pd.read_csv('Projeto10/dados/dataset2.csv')

# %%
dados.shape
# Out:
# (3818, 92)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %%
dados.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.818000e+03  3.818000e+03  3.818000e+03          3816.000000
# mean   5.550111e+06  2.016010e+13  1.578556e+07             7.157757
# std    2.962660e+06  0.000000e+00  1.458382e+07            28.628149
# min    3.335000e+03  2.016010e+13  4.193000e+03             1.000000
# 25%    3.258256e+06  2.016010e+13  3.275204e+06             1.000000
# 50%    6.118244e+06  2.016010e+13  1.055814e+07             1.000000
# 75%    8.035127e+06  2.016010e+13  2.590309e+07             3.000000
# max    1.034016e+07  2.016010e+13  5.320861e+07           502.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                3816.000000  3818.000000  3818.000000   3818.000000
# mean                    7.157757    47.628961  -122.333103      3.349398
# std                    28.628149     0.043052     0.031745      1.977599
# ...

# %%
dados.head(5)
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
dados.dtypes.value_counts()
# Out:
# object     62
# float64    17
# int64      13
# dtype: int64

# %%
dados['price'].sample
# Out:
# <bound method NDFrame.sample of 0        $85.00
# 1       $150.00
# 2       $975.00
# 3       $100.00
# 4       $450.00
#          ...
# 3813    $359.00
# 3814     $79.00
# 3815     $93.00
# 3816     $99.00
# 3817     $87.00
# Name: price, Length: 3818, dtype: object>

# %%
dados.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %%
df1 = dados
fontsize = 10
fig, axes = plt.subplots(figsize = (12,8))
sns.violinplot(x = 'host_is_superhost', y = 'review_scores_rating', data = df1, ax = axes)
axes.set_title('Superhost tem padrão de avaliação diferente?')
plt.show()

# %%
dados['price'] = dados['price'].str.replace('$','').str.replace('%','').str.replace(',','').astype('float64')
df2 = dados
fontsize = 10
fig, axes = plt.subplots(figsize = (12,8))
sns.violinplot(x = 'host_is_superhost', y = 'price', data = df2, ax = axes)
axes.set_title('Superhost tem padrão de preço diferente?')
plt.show()
# Out:
# C:\Users\LuizCláudioSouza\AppData\Local\Temp\ipykernel_25628\699849852.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados['price'] = dados['price'].str.replace('$','').str.replace('%','').str.replace(',','').astype('float64')

# %%
#!pip install -q yfinance

# %%
#!pip install -q pandas_datareader

# %%
import pandas_datareader
import sqlite3
import yfinance

# %%
AZN = 'AZN'

# %%
AZN = yfinance.download(AZN)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
AZN.shape
# Out:
# (7546, 6)

# %%
AZN.head(5)
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 1993-05-12  5.291667  5.291667  5.020833  5.041667   1.778690  414000
# 1993-05-13  5.000000  5.000000  4.791667  4.854167   1.712541  792600
# 1993-05-14  4.875000  4.875000  4.791667  4.791667   1.690490  646200
# 1993-05-17  4.833333  4.895833  4.833333  4.895833   1.727240   68400
# 1993-05-18  4.895833  4.895833  4.833333  4.854167   1.712541   69000

# %%
AZN.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  7546.000000  7546.000000  7546.000000  7546.000000  7546.000000
# mean     27.019650    27.224029    26.824154    27.031559    18.794415
# std      13.884523    13.987901    13.774100    13.878858    15.802891
# min       4.479167     4.500000     4.479167     4.479167     1.580242
# 25%      20.070000    20.310625    19.876250    20.111250     9.047882
# 50%      23.582500    23.742500    23.434999    23.605000    12.824311
# 75%      32.860001    33.080002    32.651250    32.878751    25.349640
# max      76.500000    76.559998    75.660004    75.809998    75.809998
#
#              Volume
# count  7.546000e+03
# mean   2.979123e+06
# std    3.388605e+06
# min    2.400000e+03
# 25%    9.241000e+05
# 50%    2.256800e+06
# 75%    3.934175e+06
# max    6.554020e+07

# %%
AZN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7546 entries, 1993-05-12 to 2023-04-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       7546 non-null   float64
#  1   High       7546 non-null   float64
#  2   Low        7546 non-null   float64
#  3   Close      7546 non-null   float64
#  4   Adj Close  7546 non-null   float64
#  5   Volume     7546 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 412.7 KB

# %%
conn = sqlite3.connect("Projeto10/dados/AZN.db")
c = conn.cursor()

# %%
c.execute("""Select * from AZN""")
rows = c.fetchall()
rows
# Out:
# [('1993-05-12 00:00:00',
#   5.2916669845581055,
#   5.2916669845581055,
#   5.0208330154418945,
#   5.0416669845581055,
#   1.8172520399093628,
#   414000),
#  ('1993-05-13 00:00:00',
#   5.0,
#   5.0,
#   4.7916669845581055,
#   4.8541669845581055,
#   1.7496682405471802,
#   792600),
#  ('1993-05-14 00:00:00',
#   4.875,
#   4.875,
#   4.7916669845581055,
#   4.7916669845581055,
#   1.7271405458450317,
#   646200),
#  ('1993-05-17 00:00:00',
#   4.8333330154418945,
#   4.8958330154418945,
#   4.8333330154418945,
#   4.8958330154418945,
#   1.7646864652633667,
#   68400),
#  ('1993-05-18 00:00:00',
#   4.8958330154418945,
#   4.8958330154418945,
#   4.8333330154418945,
#   4.8541669845581055,
#   1.7496682405471802,
#   69000),
#  ('1993-05-19 00:00:00',
#   4.8541669845581055,
#   4.875,
#   4.8541669845581055,
#   4.875,
#   1.7571772336959839,
#   72000),
#  ('1993-05-20 00:00:00',
#   4.875,
#   4.8958330154418945,
#   4.8541669845581055,
#   4.875,
#   1.7571772336959839,
# ...

# %%
AZN.to_excel("Projeto10/dados/AZN.xlsx")

# %%
df = pd.read_excel("Projeto10/dados/AZN.xlsx")

# %%
df.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close  Volume
# 0 1993-05-12  5.291667  5.291667  5.020833  5.041667   1.778690  414000
# 1 1993-05-13  5.000000  5.000000  4.791667  4.854167   1.712541  792600
# 2 1993-05-14  4.875000  4.875000  4.791667  4.791667   1.690490  646200
# 3 1993-05-17  4.833333  4.895833  4.833333  4.895833   1.727240   68400
# 4 1993-05-18  4.895833  4.895833  4.833333  4.854167   1.712541   69000

# %%
x = df['Date']
y = df['Close']
plt.figure(figsize = (12,6), dpi = 100)
plt.plot(x, y, label = "AZN")
plt.title('Cotação das ações da Astrazeneca ao longo do tempo',
         fontdict = {'fontname': 'Comic Sans MS', 'fontsize': 16})

plt.xlabel('Tempo')
plt.ylabel('Preço da Ação')
plt.show()

# %%
dados = pd.read_csv('Projeto10/dados/dataset3.csv')

# %%
sns.set_style('darkgrid')
sns.set(font_scale = 1.2)

# %%
dados.head()
# Out:
#       ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# 1         0     6/15/14        0       464  ...                  7
# 2         1     5/13/14        0       134  ...                  5
# 3         1     5/11/14        0        10  ...                  2
# 4         0      4/8/14        0         6  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %%
dados.shape
# Out:
# (2240, 28)

# %%
dados.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ',
#        'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
dados.rename({' Income ': 'Income'}, axis = 1, inplace = True)

# %%
dados['Income'] =  dados['Income'].str.replace('$','')
# Out:
# C:\Users\LuizCláudioSouza\AppData\Local\Temp\ipykernel_25628\2391154194.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados['Income'] =  dados['Income'].str.replace('$','')

# %%
dados['Income'] =  dados['Income'].str.replace(',','').astype(float)

# %%
dados['Dt_Customer'] = pd.to_datetime(dados['Dt_Customer'])

# %%
dados.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %%
dados['Income'] = dados['Income'].fillna(dados['Income'].mean())

# %%
dados['Customer_Age_When_Enrolled'] = dados['Dt_Customer'].dt.year - dados['Year_Birth']

# %%
dados[dados['Customer_Age_When_Enrolled'] >=80]
# Out:
#          ID  Year_Birth Education Marital_Status   Income  Kidhome  Teenhome  \
# 513   11004        1893  2n Cycle         Single  60182.0        0         1
# 827    1150        1899       PhD       Together  83532.0        0         0
# 2233   7829        1900  2n Cycle       Divorced  36640.0        1         0
#
#      Dt_Customer  Recency  MntWines  ...  NumWebVisitsMonth  AcceptedCmp3  \
# 513   2014-05-17       23         8  ...                  4             0
# 827   2013-09-26       36       755  ...                  1             0
# 2233  2013-09-26       99        15  ...                  5             0
#
#       AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  \
# 513              0             0             0             0         0
# 827              0             1             0             0         0
# 2233             0             0             0             0         0
#
#       Complain  Country  Customer_Age_When_Enrolled
# ...

# %%
dados['Total Spent'] = (dados['MntFishProducts'] + dados['MntWines'] + dados['MntSweetProducts']
                       +dados['MntFruits']+dados['MntMeatProducts']+dados['MntGoldProds'])

# %%
dados['Total Purchases'] = (dados['NumDealsPurchases'] + dados['NumWebPurchases'] 
                            + dados['NumStorePurchases'] +dados['NumCatalogPurchases'])

# %%
dados['Kids_Teen_at_home'] = dados['Kidhome'] + dados['Teenhome']

# %%
dados = dados.drop(['Kidhome', 'Teenhome'], axis = 1)

# %%
plt.figure(figsize = (6,6))
sns.boxplot(data = dados['Year_Birth'], color = 'r')
# Out:
# <Axes: >

# %%
dados = dados[dados['Year_Birth'] >=1920]

# %%
plt.figure(figsize = (6,6))
sns.boxplot(data = dados['Year_Birth'], color = 'r')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (6,6))
sns.violinplot(data = dados['Year_Birth'], color = 'purple')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (16,8))
sns.countplot(data = dados['Year_Birth'], color = 'purple', x = dados['Education'])
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
estado_civil = dados['Marital_Status'].value_counts().to_frame('Count')

# %%
estado_civil
# Out:
#           Count
# Married     864
# Together    579
# Single      479
# Divorced    231
# Widow        77
# Alone         3
# YOLO          2
# Absurd        2
